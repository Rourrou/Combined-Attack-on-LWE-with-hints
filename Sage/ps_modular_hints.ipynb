# %%
# DDGR20，嵌入近似hint，l-noisy < <v,s> < l+noisy
cd framework

# %%
load("../framework/instance_gen.sage")
import numpy as np
import random

# %%
n = 128
m = n
q = 3329
D_s = build_centered_binomial_law(3)
D_e = D_s
A, b, s, dbdd = initialize_from_LWE_instance(DBDD_predict, n, q, m, D_e, D_s)
print(s)
beta, delta = dbdd.estimate_attack()
_ = dbdd.integrate_q_vectors(q, report_every=20)

# %%
nph_Kyber128 = [0,5,10,15,20,25,30,35,40,45,50,55,60,65,100,200,300,400,500,520,540,560,580,600,620,640,660,680,700,720,740,760,780,800,820,840,860,880,900]
dis_Kyber128_our = [20.66,19.46,19.28,17.08,14.27,12.96,9.85,9.2,8.4,7.88,7.45,7.01,6.52,5.91,5.31,3.87,3.27,2.31,1.57,1.21]
dis_Kyber128_bp = []

num_hint = 901
BETA = []
index = 0
for j in range(num_hint):
    if j == nph_Kyber128[index]:
        _ = dbdd.integrate_q_vectors(q, report_every=20)
        st = dis_Kyber128_our[index]/dis_Kyber128_our[0]
        beta, delta = dbdd.estimate_attack_SMY(st)
        print("beta: ", beta)
        BETA.append(beta)
        index += 1
print(BETA)

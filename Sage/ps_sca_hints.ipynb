# %%
# DDGR20，嵌入近似hint，l-noisy < <v,s> < l+noisy
cd framework

# %%
load("../framework/instance_gen.sage")
import numpy as np
import random

# %%
n = 512
m = n
q = 3329
D_s = build_centered_binomial_law(3)
D_e = D_s
A, b, s, dbdd = initialize_from_LWE_instance(DBDD_predict, n, q, m, D_e, D_s)
print(s)
beta, delta = dbdd.estimate_attack()

# %%
nph_Kyber512 = [0, 40, 80, 120, 160, 200, 240, 280, 320, 360, 400, 440, 480, 520, 560, 600, 640, 680, 720, 760, 800, 840, 880, 920, 960, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500, 8000]
dis_Kyber512_our = [39.56, 40.03, 40.4, 40.4, 40.31, 40.09, 39.85, 39.7, 39.23, 39.2, 38.86, 38.64, 38.33, 37.92, 37.5, 37.2, 37.1, 36.7, 36.54, 36.23, 35.97, 35.76, 35.48, 35.16, 34.96, 34.77, 31.61, 29.06, 26.76, 24.78, 23.25, 21.82, 20.67, 19.82, 18.78, 17.88, 17.19, 16.42, 15.81, 14.87]
BETA = []
for i in range(len(nph_Kyber512)):
    st = dis_Kyber512_our[i]/dis_Kyber512_our[0]
    beta, delta = dbdd.estimate_attack_SMY(st)
    print("beta: ", beta)
    BETA.append(beta)
print(BETA)
